# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 2
# #**Practica 1**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import math as mt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres=["Oscar","Paco","Paty","Laura","Ruben","Luis","Lucy","Alberto","Juan","Danny"]
n=len(nombres)
r=2
Cn=mt.factorial(n)/(mt.factorial(r)*mt.factorial(n-r))
print("Existen ", Cn , "posibles combinaciones sin repeticion total de ", n ," nombres en grupos de ", r ," en ", r)
print("Aqui las combinaciones")
combinaciones_nombre=list(combinations(nombres,r))
for combinacion in combinaciones_nombre:
    print(combinacion)
# Out:
# Existen  45.0 posibles combinaciones sin repeticion total de  10  nombres en grupos de  2  en  2
# Aqui las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Paty')
# ('Oscar', 'Laura')
# ('Oscar', 'Ruben')
# ('Oscar', 'Luis')
# ('Oscar', 'Lucy')
# ('Oscar', 'Alberto')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Paty')
# ('Paco', 'Laura')
# ('Paco', 'Ruben')
# ('Paco', 'Luis')
# ('Paco', 'Lucy')
# ('Paco', 'Alberto')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Paty', 'Laura')
# ('Paty', 'Ruben')
# ('Paty', 'Luis')
# ('Paty', 'Lucy')
# ('Paty', 'Alberto')
# ('Paty', 'Juan')
# ('Paty', 'Danny')
# ('Laura', 'Ruben')
# ('Laura', 'Luis')
# ('Laura', 'Lucy')
# ('Laura', 'Alberto')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Ruben', 'Luis')
# ('Ruben', 'Lucy')
# ('Ruben', 'Alberto')
# ('Ruben', 'Juan')
# ('Ruben', 'Danny')
# ('Luis', 'Lucy')
# ('Luis', 'Alberto')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Lucy', 'Alberto')
# ('Lucy', 'Juan')
# ('Lucy', 'Danny')
# ('Alberto', 'Juan')
# ...
