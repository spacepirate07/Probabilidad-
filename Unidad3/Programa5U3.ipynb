# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Programa5U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
# #Unidad 3
# #**Programa 5: Grafica de distribucion de probabilidad**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,6,7,8,9,10])
p=np.array([0.05,0.10,0.20,0.30,0.25,0.10])
esperanza=np.sum(x*p)
esperanza_cuadrado=np.sum(x**2*p)
varianza=esperanza_cuadrado-esperanza**2
desviacion_estandar=np.sqrt(varianza)
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion_estandar:.2f}")
plt.stem(x, p, basefmt=" ", linefmt='b-', markerfmt='bo')
plt.title("Distribucion de Probabilidad Discreta\ncon Media y Desviacion Estandar")
plt.xlabel("Valores de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.axvline(x=esperanza, color='red', linestyle='--', label=f"Media E(X) = {esperanza:.2f}")
plt.axvspan(esperanza - desviacion_estandar, esperanza + desviacion_estandar, color='red', alpha=0.2, label=f"±1 Desv. Estandar (σ={desviacion_estandar:.2f})")
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)
plt.show()
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviacion Estandar = 1.30
