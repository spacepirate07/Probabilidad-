# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Programa1U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
# #Unidad 3
# #**Practica 1**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import matplotlib.pyplot as plt
#Valores de la variable aleatoria
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]
#Verificar suma=1
print("Suma de probabilidades:",sum(p))
#Graficar distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.xlabel("Calificacion")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0
