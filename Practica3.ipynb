# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 1
# #**Practica 3: Tablas de frecuencias**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [39, 45, 31, 70, 57, 58, 48, 29, 39, 28, 54, 64, 18, 70, 30, 21, 31, 61, 46, 20, 49, 66, 24, 21, 50, 44, 55, 18, 49, 44, 44, 36, 51, 41, 59, 61, 39, 42, 68, 70, 32, 47, 45, 49, 29, 43, 24, 40, 36, 61, 34, 58, 58, 61, 36, 51, 46, 37, 30, 37, 65, 64, 48, 47, 41, 20, 57, 49, 39, 48, 37, 45, 54, 66, 44, 20, 54, 57, 68, 49, 33, 30, 69, 51, 58, 50, 25, 40, 21, 20, 68, 51, 18, 29, 52, 47, 46, 70, 34, 49]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    39
# 1    45
# 2    31
# 3    70
# 4    57

# %%
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
print("Tabla de distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 19    18           3
# 5     20           4
# 13    21           3
# 22    24           2
# 38    25           1
# 29    28           1
# 9     29           3
# 14    30           3
# 21    31           2
# 33    32           1
# 36    33           1
# 25    34           2
# 17    36           3
# 16    37           3
# 1     39           4
# 24    40           2
# 28    41           2
# 31    42           1
# 32    43           1
# 4     44           4
# 12    45           3
# 8     46           3
# 20    47           3
# 11    48           3
# 0     49           6
# 27    50           2
# 7     51           4
# 39    52           1
# 15    54           3
# 30    55           1
# 10    57           3
# 2     58           4
# 34    59           1
# 6     61           4
# 23    64           2
# 35    65           1
# 26    66           2
# 18    68           3
# 37    69           1
# 3     70           4

# %%
tabla_frecuencias['Frec. Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 19    18           3            0.03
# 5     20           4            0.04
# 13    21           3            0.03
# 22    24           2            0.02
# 38    25           1            0.01
# 29    28           1            0.01
# 9     29           3            0.03
# 14    30           3            0.03
# 21    31           2            0.02
# 33    32           1            0.01
# 36    33           1            0.01
# 25    34           2            0.02
# 17    36           3            0.03
# 16    37           3            0.03
# 1     39           4            0.04
# 24    40           2            0.02
# 28    41           2            0.02
# 31    42           1            0.01
# 32    43           1            0.01
# 4     44           4            0.04
# 12    45           3            0.03
# 8     46           3            0.03
# 20    47           3            0.03
# 11    48           3            0.03
# 0     49           6            0.06
# 27    50           2            0.02
# 7     51           4            0.04
# 39    52           1            0.01
# 15    54           3            0.03
# 30    55           1            0.01
# 10    57           3            0.03
# 2     58           4            0.04
# 34    59           1            0.01
# 6     61           4            0.04
# 23    64           2            0.02
# 35    65           1            0.01
# 26    66           2            0.02
# 18    68           3            0.03
# 37    69           1            0.01
# 3     70           4            0.04

# %%
tabla_frecuencias['Frec. Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual
# 19    18           3            0.03               3.0
# 5     20           4            0.04               4.0
# 13    21           3            0.03               3.0
# 22    24           2            0.02               2.0
# 38    25           1            0.01               1.0
# 29    28           1            0.01               1.0
# 9     29           3            0.03               3.0
# 14    30           3            0.03               3.0
# 21    31           2            0.02               2.0
# 33    32           1            0.01               1.0
# 36    33           1            0.01               1.0
# 25    34           2            0.02               2.0
# 17    36           3            0.03               3.0
# 16    37           3            0.03               3.0
# 1     39           4            0.04               4.0
# 24    40           2            0.02               2.0
# 28    41           2            0.02               2.0
# 31    42           1            0.01               1.0
# 32    43           1            0.01               1.0
# 4     44           4            0.04               4.0
# 12    45           3            0.03               3.0
# 8     46           3            0.03               3.0
# 20    47           3            0.03               3.0
# 11    48           3            0.03               3.0
# 0     49           6            0.06               6.0
# 27    50           2            0.02               2.0
# 7     51           4            0.04               4.0
# 39    52           1            0.01               1.0
# 15    54           3            0.03               3.0
# 30    55           1            0.01               1.0
# 10    57           3            0.03               3.0
# 2     58           4            0.04               4.0
# 34    59           1            0.01               1.0
# 6     61           4            0.04               4.0
# 23    64           2            0.02               2.0
# 35    65           1            0.01               1.0
# 26    66           2            0.02               2.0
# 18    68           3            0.03               3.0
# 37    69           1            0.01               1.0
# 3     70           4            0.04               4.0

# %%
tabla_frecuencias['Frec. Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 19    18           3            0.03               3.0                3
# 5     20           4            0.04               4.0                7
# 13    21           3            0.03               3.0               10
# 22    24           2            0.02               2.0               12
# 38    25           1            0.01               1.0               13
# 29    28           1            0.01               1.0               14
# 9     29           3            0.03               3.0               17
# 14    30           3            0.03               3.0               20
# 21    31           2            0.02               2.0               22
# 33    32           1            0.01               1.0               23
# 36    33           1            0.01               1.0               24
# 25    34           2            0.02               2.0               26
# 17    36           3            0.03               3.0               29
# 16    37           3            0.03               3.0               32
# 1     39           4            0.04               4.0               36
# 24    40           2            0.02               2.0               38
# 28    41           2            0.02               2.0               40
# 31    42           1            0.01               1.0               41
# 32    43           1            0.01               1.0               42
# 4     44           4            0.04               4.0               46
# 12    45           3            0.03               3.0               49
# 8     46           3            0.03               3.0               52
# 20    47           3            0.03               3.0               55
# 11    48           3            0.03               3.0               58
# 0     49           6            0.06               6.0               64
# 27    50           2            0.02               2.0               66
# 7     51           4            0.04               4.0               70
# 39    52           1            0.01               1.0               71
# 15    54           3            0.03               3.0               74
# 30    55           1            0.01               1.0               75
# 10    57           3            0.03               3.0               78
# 2     58           4            0.04               4.0               82
# 34    59           1            0.01               1.0               83
# 6     61           4            0.04               4.0               87
# 23    64           2            0.02               2.0               89
# 35    65           1            0.01               1.0               90
# 26    66           2            0.02               2.0               92
# 18    68           3            0.03               3.0               95
# 37    69           1            0.01               1.0               96
# 3     70           4            0.04               4.0              100

# %%
import math
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     39
# 1     45
# 2     31
# 3     70
# 4     57
# ..   ...
# 95    47
# 96    46
# 97    70
# 98    34
# 99    49
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1+math.log2(n))
print("Valor de n = ", n ,"\nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencia=pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    20
# 1  (40.286, 47.714]    17
# 2  (32.857, 40.286]    15
# 3    (62.571, 70.0]    13
# 4  (17.947, 25.429]    13
# 5  (55.143, 62.571]    12
# 6  (25.429, 32.857]    10

# %%
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (17.947, 25.429]    13
# 6  (25.429, 32.857]    10
# 2  (32.857, 40.286]    15
# 1  (40.286, 47.714]    17
# 0  (47.714, 55.143]    20
# 5  (55.143, 62.571]    12
# 3    (62.571, 70.0]    13

# %%
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac']=tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Por Ac']=tabla_frecuencia['Frec Porc'].cumsum()
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 4  (17.947, 25.429]    13      0.13       13.0       13         0.13
# 6  (25.429, 32.857]    10      0.10       10.0       23         0.23
# 2  (32.857, 40.286]    15      0.15       15.0       38         0.38
# 1  (40.286, 47.714]    17      0.17       17.0       55         0.55
# 0  (47.714, 55.143]    20      0.20       20.0       75         0.75
# 5  (55.143, 62.571]    12      0.12       12.0       87         0.87
# 3    (62.571, 70.0]    13      0.13       13.0      100         1.00
#
#    Frec Por Ac
# 4         13.0
# 6         23.0
# 2         38.0
# 1         55.0
# 0         75.0
# 5         87.0
# 3        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
