# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 1
# ##**Practica 2. Maximo, minimo, rango y dispersion de datos.**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#Generamos 100 numeros aleatorios que representan la produccion en metros de tela de 100 dias
fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [54.17, 63.92, 79.28, 94.21, 95.57, 78.24, 89.57, 89.19, 75.4, 63.0, 84.64, 98.64, 89.06, 92.49, 74.83, 70.25, 56.4, 51.32, 94.55, 54.81, 58.07, 72.44, 70.47, 91.49, 93.52, 79.66, 97.23, 76.11, 60.32, 55.84, 87.22, 62.35, 57.93, 58.74, 63.58, 77.16, 81.98, 63.53, 53.2, 55.82, 90.34, 82.83, 91.58, 97.36, 53.6, 63.64, 98.76, 59.13, 83.83, 99.49, 54.41, 52.17, 64.27, 65.35, 70.32, 75.51, 86.71, 74.76, 92.94, 56.22, 63.6, 96.48, 69.69, 64.77, 90.4, 89.08, 76.75, 51.05, 51.22, 61.06, 67.16, 97.29, 64.54, 77.44, 62.24, 88.76, 94.51, 55.98, 64.78, 78.54, 64.65, 58.26, 62.13, 79.3, 53.62, 99.84, 98.9, 66.55, 92.64, 56.08, 86.66, 93.82, 83.29, 62.64, 70.04, 52.92, 55.01, 54.35, 61.92, 53.29]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [50.66, 95.34, 78.59, 77.91, 95.54, 81.35, 76.59, 68.19, 98.63, 79.94, 86.87, 87.79, 74.49, 95.97, 98.13, 77.72, 92.95, 68.21, 96.75, 52.09, 80.67, 68.06, 91.01, 63.74, 52.13, 79.46, 79.1, 73.26, 62.02, 74.93, 55.28, 91.39, 69.86, 52.55, 90.28, 91.8, 70.81, 68.03, 56.81, 66.85, 58.44, 67.59, 96.67, 52.13, 52.73, 66.87, 52.71, 84.28, 52.52, 63.15, 82.44, 58.11, 69.86, 76.18, 54.34, 73.11, 71.43, 76.27, 78.42, 82.38, 51.8, 87.1, 66.13, 82.2, 56.06, 62.19, 50.62, 92.48, 59.88, 64.32, 69.08, 70.38, 72.18, 79.4, 67.12, 66.34, 72.55, 57.47, 67.84, 96.93, 92.51, 95.37, 84.35, 50.67, 66.11, 78.76, 87.53, 68.32, 88.6, 80.67, 82.94, 98.75, 61.3, 83.29, 98.28, 94.83, 58.87, 54.24, 98.48, 65.79]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar1_fabrica1=stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "Media =", media1, "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1, "\n Minimo =", minimo1, "\n Rango =", rango1)
print(desviacion_estandar1_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 73.5067
#  Mediana = 70.395
#  Moda = 54.17
#  Maximo = 99.84
#  Minimo = 51.05
#  Rango = 48.790000000000006
# 15.508102675568008

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar2_fabrica2=stdev(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "Media =", media2, "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2, "\n Minimo =", minimo2, "\n Rango =", rango2)
print(desviacion_estandar2_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 74.2311
#  Mediana = 73.185
#  Moda = 80.67
#  Maximo = 98.75
#  Minimo = 50.62
#  Rango = 48.13
# 14.48606679195599
