# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Programa3U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
# #Unidad 3
# #**Programa 3: Varianza y desviacion**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import math
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]
esperanza=0
for i in range(len(x)):
  esperanza+=x[i]*p[i]
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado+=(x[i]**2)*p[i]
varianza=esperanza_cuadrado-esperanza**2
desviacion=math.sqrt(varianza)
print(f"E(x) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion estandar = {desviacion:.2f}")
#
# Out:
# E(x) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviacion estandar = 1.30
