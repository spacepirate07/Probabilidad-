# %% [markdown]
# <a href="https://colab.research.google.com/github/spacepirate07/Probabilidad-/blob/main/Programa6U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
# #**Unidad 3**
# #**Programa 6**
# ##Facilitador: Dr. Jose Gabriel Rodriguez Rivas
# ##Alumno: Erick Daniel Galarza Garcia

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3,4,5])
p=np.array([0.10,0.25,0.30,0.20,0.10,0.05])
print("Suma de probabilidades:",sum(p))
esperanza=np.sum(x*p)
esperanza_cuadrado=np.sum(x**2*p)
varianza=esperanza_cuadrado-esperanza**2
desviacion_estandar=np.sqrt(varianza)
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion_estandar:.2f}")
F=np.cumsum(p)
for xi,fi in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")
plt.step(x, F, where='post')
plt.title("Funcion de distribucion acumulada")
plt.xlabel("Numero de celulas anormales")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0,1.05)
plt.show()
# Out:
# Suma de probabilidades: 0.9999999999999999
# E(X) = 2.10
# E(X^2) = 6.10
# Varianza = 1.69
# Desviacion Estandar = 1.30
# F(0) = 0.10
# F(1) = 0.35
# F(2) = 0.65
# F(3) = 0.85
# F(4) = 0.95
# F(5) = 1.00

# %% [markdown]
# Promedio esperado de células anormales
#
# El valor esperado es:
# E(X)=2.10
#
# Esto significa que, en promedio, se esperan alrededor de 2.1 células anormales por muestra. En contexto biomédico:
#
# La presencia de células anormales es frecuente, pero no elevada.
# La mayoría de las muestras presentan pocos casos anormales, lo cual puede considerarse un nivel moderado.
#
# Variabilidad entre las muestras
#
# Varianza=1.69, σ=
# √1.69
# =1.30
#
# Interpretación:
#
# La desviación estándar de 1.30 indica una variabilidad moderada.
#
# La mayoría de las muestras se encuentran aproximadamente entre:
#
# 2.10±1.30⇒(0.8, 3.4)
#
# En términos prácticos:
#
# Es común observar entre 1 y 3 células anormales.
# Valores más altos (4 o 5) son menos frecuentes.
#
# Interpretación de la función acumulada
# F(x)
#
# F(0)=0.10 → 10% de probabilidad de no encontrar células anormales
#
# F(1)=0.35 → 35% de tener 1 o menos
#
# F(2)=0.65 → 65% de tener 2 o menos
#
# F(3)=0.85 → 85% de tener 3 o menos
#
# F(4)=0.95 → 95% de tener 4 o menos
#
# F(5)=1.00 → certeza total
#
# Interpretación clave:
#
# Hay una alta probabilidad de valores bajos (0–2 células).
# Es muy probable (85%) que una muestra tenga máximo 3 células anormales.
# Solo un 5% de las muestras presentan valores altos (5 células).
